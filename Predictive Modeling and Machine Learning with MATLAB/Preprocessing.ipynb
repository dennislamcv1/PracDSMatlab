# %%
import pandas as pd

# %%
df = pd.read_csv("taxidataJun.csv")

# %%
df
# Out:
#         Vendor           PickupTime          DropoffTime  Passengers  \
# 0            1  2015-06-02 11:20:30  2015-06-02 11:33:02           1
# 1            2  2015-06-02 11:19:39  2015-06-02 11:44:31           1
# 2            2  2015-06-02 11:19:40  2015-06-02 11:52:27           1
# 3            1  2015-06-02 11:23:03  2015-06-02 11:39:17           2
# 4            2  2015-06-02 11:23:15  2015-06-02 11:42:31           1
# ...        ...                  ...                  ...         ...
# 239981       1  2015-06-30 21:53:15  2015-06-30 22:06:56           1
# 239982       1  2015-06-30 21:54:06  2015-06-30 22:08:26           1
# 239983       2  2015-06-30 21:54:20  2015-06-30 21:59:27           1
# 239984       2  2015-06-30 21:54:20  2015-06-30 22:20:37           5
# 239985       2  2015-06-30 21:54:08  2015-06-30 21:58:48           5
#
#         Distance  PickupLon  PickupLat  RateCode HeldFlag  DropoffLon  ...  \
# ...

# %%
df["FarePerMile"] = df["Fare"] / df["Distance"]

# %%
df.head()
# Out:
#    Vendor           PickupTime          DropoffTime  Passengers  Distance  \
# 0       1  2015-06-02 11:20:30  2015-06-02 11:33:02           1      2.00
# 1       2  2015-06-02 11:19:39  2015-06-02 11:44:31           1      1.22
# 2       2  2015-06-02 11:19:40  2015-06-02 11:52:27           1      4.45
# 3       1  2015-06-02 11:23:03  2015-06-02 11:39:17           2      1.20
# 4       2  2015-06-02 11:23:15  2015-06-02 11:42:31           1      2.12
#
#    PickupLon  PickupLat  RateCode HeldFlag  DropoffLon  ...  Tax   Tip  Tolls  \
# 0 -73.974861  40.741905  Standard        N  -73.996246  ...  0.5  2.16    0.0
# 1 -73.993561  40.749969  Standard        N  -73.985519  ...  0.5  3.26    0.0
# 2 -73.991364  40.749580  Standard        N  -74.013756  ...  0.5  0.00    0.0
# 3 -73.980804  40.753605  Standard        N  -73.966759  ...  0.5  2.35    0.0
# 4 -74.004471  40.737846  Standard        N  -73.982628  ...  0.5  0.00    0.0
#
# ...

# %%
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 239986 entries, 0 to 239985
# Data columns (total 24 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Vendor        239986 non-null  int64
#  1   PickupTime    239986 non-null  object
#  2   DropoffTime   239986 non-null  object
#  3   Passengers    239986 non-null  int64
#  4   Distance      239986 non-null  float64
#  5   PickupLon     239986 non-null  float64
#  6   PickupLat     239986 non-null  float64
#  7   RateCode      239986 non-null  object
#  8   HeldFlag      239986 non-null  object
#  9   DropoffLon    239986 non-null  float64
#  10  DropoffLat    239986 non-null  float64
#  11  PayType       239986 non-null  object
#  12  Fare          239986 non-null  float64
#  13  ExtraCharge   239986 non-null  float64
#  14  Tax           239986 non-null  float64
#  15  Tip           239986 non-null  float64
#  16  Tolls         239986 non-null  float64
# ...

# %%
#df.to_csv("added.csv", index=False)
